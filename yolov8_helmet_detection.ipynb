# %% [markdown]
# # Printing current working directory

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# # Install ultralytics and checks

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %% [markdown]
# # Importing YOLO class and functions

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # Running YOLO Object Detection Task

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 78.6MB/s]
#
# 2024-04-24 11:13:21.851570: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 11:13:21.851616: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 11:13:21.852970: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-24 11:13:22.908333: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...

# %% [markdown]
# # Mounting Google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  antifungal   'Colab Notebooks'			 dataset.zip
# 'april edit'  'data capturing August 2023.doc'	'Edited Pics'

# %% [markdown]
# # Unzip the dataset folder

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/images/training/BikesHelmets577.txt
#   inflating: dataset/images/training/BikesHelmets578.png
#   inflating: dataset/images/training/BikesHelmets578.txt
#   inflating: dataset/images/training/BikesHelmets579.png
#   inflating: dataset/images/training/BikesHelmets579.txt
#   inflating: dataset/images/training/BikesHelmets58.png
#   inflating: dataset/images/training/BikesHelmets58.txt
#   inflating: dataset/images/training/BikesHelmets580.png
#   inflating: dataset/images/training/BikesHelmets580.txt
#   inflating: dataset/images/training/BikesHelmets581.png
#   inflating: dataset/images/training/BikesHelmets581.txt
#   inflating: dataset/images/training/BikesHelmets582.png
#   inflating: dataset/images/training/BikesHelmets582.txt
#   inflating: dataset/images/training/BikesHelmets583.png
#   inflating: dataset/images/training/BikesHelmets583.txt
#   inflating: dataset/images/training/BikesHelmets584.png
# ...

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/dataset/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 134MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
